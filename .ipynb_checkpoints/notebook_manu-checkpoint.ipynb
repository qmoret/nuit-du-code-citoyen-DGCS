# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns; sns.set_style("darkgrid")
from datetime import datetime,timedelta
# Out:
# <style>.container { width:100% !important; }</style>

# %%
a4dims = (40,20)

# %%
df = pd.read_csv('extract_115.csv',sep=';')

# %% [markdown]
# ### Demande 115
#
# Voici les explications des préfixes de nom de colonne
# * *Per* : PERSONNE
# * *Dso* : DIAGNOSTIC SOCIAL
# * *Fic* : FICHE
# * *Sad* : SITUATION ADMINISTRATIVE
# * *Sfa* : SITUTATION FAMILLE
# * *Sso* : SITUATION SOCIALE
# * *Dhe* : DEMANDE HEBERGEMENT
# * *Rep* : REPONSE
# * *Gro* : GROUPE DE PLACE ASSOCIE A LA REPONSE
# * *Str* : Structure du groupe de place associé à la réponse
#
# ### Prestation 115
#
# Voici les explications des préfixes de nom de colonne
# * *Per* : PERSONNE
# * *Dso* : DIAGNOSTIC SOCIAL
# * *Fic* : FICHE
# * *Sad* : SITUATION ADMINISTRATIVE
# * *Sfa* : SITUTATION FAMILLE
# * *Sso* : SITUATION SOCIALE
# * *Pre* : PRESTATION

# %% [markdown]
# # Cleaning

# %%
df['dem_date'] = pd.to_datetime(df['dem_date'],format = '%d/%m/%Y')

# %%
# df['numero_demande']
demandes = df[['per_id','dem_date']].drop_duplicates()
demandes[['per_id','dem_date']].sort_values(by=['per_id','dem_date'])
# Out:
#          per_id   dem_date
# 16426    780689 2017-09-16
# 11742  40861604 2017-07-22
# 11743  40861604 2017-07-24
# 11744  40861604 2017-07-25
# 11745  40861604 2017-07-28
# 11746  40861604 2017-08-01
# 11747  40861604 2017-08-03
# 11748  40861604 2017-08-08
# 11749  40861604 2017-08-10
# 11750  40861604 2017-08-11
# 11751  40861604 2017-08-14
# 11752  40861604 2017-08-15
# 11753  40861604 2017-08-18
# 11754  40861604 2017-08-21
# 11755  40861604 2017-08-31
# 11756  40861604 2017-09-04
# 11757  40861604 2017-09-07
# 11758  40861604 2017-09-28
# 11759  40861604 2017-09-29
# 11760  40861604 2017-10-16
# 11761  40861604 2017-11-06
# 11762  40861604 2017-11-10
# 11763  40861604 2017-11-14
# 11764  40861604 2017-11-15
# 11765  40861604 2017-11-16
# 11766  40861604 2017-11-23
# 11767  40861604 2017-11-24
# 13233  41107616 2017-08-07
# 13241  41107616 2017-08-08
# 13222  41107616 2017-08-31
# ...         ...        ...
# 26982  43394083 2018-02-12
# 26981  43394103 2018-02-12
# 26989  43396983 2018-02-12
# 26988  43396983 2018-02-13
# 26990  43396983 2018-02-14
# 26992  43399044 2018-02-12
# 26993  43402423 2018-02-12
# 26994  43402663 2018-02-12
# 26995  43403223 2018-02-12
# 26996  43403223 2018-02-13
# 26997  43403243 2018-02-12
# 26998  43403263 2018-02-12
# 26999  43404283 2018-02-13
# 27000  43404464 2018-02-13
# 27001  43405343 2018-02-13
# 27003  43406883 2018-02-13
# 27002  43406883 2018-02-14
# 27004  43406903 2018-02-13
# 27006  43407363 2018-02-13
# 27005  43407363 2018-02-14
# 27010  43409424 2018-02-13
# 27009  43409424 2018-02-14
# 27012  43411303 2018-02-13
# 27013  43411943 2018-02-13
# 26924  43413544 2018-02-13
# 26926  43413544 2018-02-14
# 27015  43414503 2018-02-14
# 27016  43432264 2018-02-14
# 27017  43432663 2018-02-14
# 27018  43432703 2018-02-14
#
# [26935 rows x 2 columns]

# %% [markdown]
# # Analyse

# %%
df.groupby('per_victime_violence')['reponse'].value_counts()
# Out:
# per_victime_violence  reponse
# NON                   OUI                14010
#                       SANS_TRAITEMENT    11131
#                       REFUS_115           1200
#                       REFUS_USAGER         636
# OUI                   OUI                   19
#                       SANS_TRAITEMENT       19
#                       REFUS_USAGER           4
# Name: reponse, dtype: int64

# %%
df[df['per_victime_violence'].isin(['OUI']) & df['reponse'].isin(['REFUS_USAGER'])]['motif_refus_usager']
# Out:
# 20289    La personne a trouvé une autre solution
# 20291    La personne a trouvé une autre solution
# 20293    La personne a trouvé une autre solution
# 26309         La personne ne s'est pas présentée
# Name: motif_refus_usager, dtype: object

# %%
df['dem_date'].value_counts()
# Out:
# 2017-11-09    209
# 2018-01-23    208
# 2017-11-16    206
# 2018-02-06    197
# 2018-01-04    192
# 2018-01-22    191
# 2018-02-05    190
# 2017-12-18    189
# 2018-01-11    189
# 2018-01-30    188
# 2018-01-09    186
# 2017-12-19    185
# 2018-02-08    184
# 2018-01-16    184
# 2018-01-08    183
# 2018-02-12    181
# 2017-12-21    181
# 2018-01-25    179
# 2017-12-26    179
# 2017-12-14    177
# 2018-02-01    176
# 2017-11-28    174
# 2017-09-26    172
# 2017-09-25    172
# 2018-01-18    172
# 2018-02-13    170
# 2018-01-29    169
# 2017-08-07    169
# 2017-10-23    169
# 2017-07-25    168
#              ...
# 2017-10-07     19
# 2017-06-24     18
# 2017-11-25     18
# 2017-10-21     17
# 2017-09-30     17
# 2017-11-11     17
# 2017-08-27     16
# 2017-10-28     16
# 2017-10-14     15
# 2017-07-30     14
# 2017-11-26     13
# 2017-06-25     13
# 2017-07-08     13
# 2017-10-01     12
# 2017-08-06     11
# 2017-07-16     11
# 2017-11-12     11
# 2017-07-01     11
# 2017-10-15     11
# 2017-09-24     11
# 2017-12-03     11
# 2017-09-09     11
# 2017-10-08     10
# 2017-10-22      8
# 2017-09-10      7
# 2017-07-02      7
# 2017-09-17      7
# 2017-11-01      7
# 2017-11-05      6
# 2017-10-29      4
# Name: dem_date, Length: 240, dtype: int64

# %%
# Réponse en fonction de la situation au moment de la demande
df.groupby('dem_situation_au_moment_de_la_demande')['reponse'].value_counts()
# Out:
# dem_situation_au_moment_de_la_demande                 reponse
# AUDA                                                  OUI                    2
#                                                       SANS_TRAITEMENT        1
# Accueil de jour, service social, associations         SANS_TRAITEMENT        2
#                                                       OUI                    1
#                                                       REFUS_USAGER           1
# Autre                                                 OUI                    8
#                                                       SANS_TRAITEMENT        7
#                                                       REFUS_115              1
#                                                       REFUS_USAGER           1
# Hébergement d'urgence                                 OUI                   53
#                                                       SANS_TRAITEMENT        5
#                                                       REFUS_115              3
# Hébergé chez famille                                  REFUS_USAGER           1
# Hôtel (hors 115)                                      REFUS_115              1
# Hôtel 115                                             OUI                    6
# Institutions publiques (hôpital, maison de retraite)  OUI                    5
#                                                       REFUS_115              3
#                                                       SANS_TRAITEMENT        1
# À la rue                                              OUI                13954
#                                                       SANS_TRAITEMENT    11134
#                                                       REFUS_115           1192
#                                                       REFUS_USAGER         637
# Name: reponse, dtype: int64

# %%
# Nombre moyen de demandes par utilisateur
df.groupby(['per_id'])['dem_id'].nunique().mean()
# out : 11
# Out:
# 11.155656482246078

# %%
# Distribution du nombre de demandes par utilisateur
sns.distplot(df.groupby(['per_id'])['dem_id'].nunique(), kde=False)

# %%
# Nombre moyen de nuits par utilisateur
demandes = df.groupby(['per_id','dem_id'],as_index=0)['rep_nb_nuit'].mean()
demandes = demandes[~demandes['rep_nb_nuit'].isnull()]
demandes.groupby(['per_id'])['rep_nb_nuit'].sum().mean()
# Out:
# 20.810306198655713

# %%
# Répartition du numbre de nuits par utilisateur
sns.distplot(demandes.groupby(['per_id'])['rep_nb_nuit'].sum(), kde=False)

# %%
# Quel est le temps moyen entre deux demandes par utilisateur ? # il faudrait l'avoir par demandeur principal
demandes = df[['per_id','dem_date']].drop_duplicates()
dem_min = demandes.groupby(['per_id'],as_index=0)['dem_date'].min()
dem_max = demandes.groupby(['per_id'],as_index=0)['dem_date'].max()
dem_count = demandes.groupby(['per_id'],as_index=0).agg({'dem_date':'nunique'})

demandes_dates = dem_min.join(dem_max,rsuffix='_max').join(dem_count,rsuffix='_count')
demandes_dates['date_diff'] = demandes_dates['dem_date_max'] - demandes_dates['dem_date']
demandes_dates['ecart_moy'] = demandes_dates.date_diff / demandes_dates['dem_date_count']
demandes_dates.head()
# Out:
#      per_id   dem_date  per_id_max dem_date_max  per_id_count  dem_date_count  \
# 0    780689 2017-09-16      780689   2017-09-16        780689               1
# 1  40861604 2017-07-22    40861604   2017-11-24      40861604              26
# 2  41107616 2017-08-07    41107616   2017-10-05      41107616              12
# 3  41117615 2017-09-06    41117615   2017-09-07      41117615               2
# 4  41169645 2017-06-19    41169645   2017-06-27      41169645               5
#
#   date_diff              ecart_moy
# 0    0 days        0 days 00:00:00
# 1  125 days 4 days 19:23:04.615384
# 2   59 days        4 days 22:00:00
# 3    1 days        0 days 12:00:00
# 4    8 days        1 days 14:24:00

# %%
# Temps moyens entre deux demandes, en jours, heures et minutes
demandes_dates['ecart_moy_jours'] = demandes_dates.ecart_moy.apply(lambda x : x.components.days)
demandes_dates['ecart_moy_heures'] = demandes_dates.ecart_moy.apply(lambda x : x.components.days*24 + x.components.hours*60)
demandes_dates['ecart_moy_minutes'] = demandes_dates.ecart_moy.apply(lambda x : x.components.days*24*60 + x.components.hours*60 + x.components.minutes)

# Répartition des temps moyens entre deux demandes, par utilisateur
sns.distplot(demandes_dates['ecart_moy_jours'], kde=False)

# %%
# Nombre d'utilisateurs, ventilés par nombre de demandes et fréquence des demandes
fig, ax = plt.subplots(figsize=a4dims)
sns.heatmap(ax=ax, data=pd.crosstab(demandes_dates['ecart_moy_jours'], demandes_dates['dem_date_count']), vmin=0, vmax=10)

# %%
# Pourcentage de d'utilisateurs faisant seulement une demande
(demandes_dates.date_diff==timedelta(0)).mean()
# 37.5%
# Out:
# 0.374896779521057

# %%
# Parmis les utilisateurs ayant fait une seule demande, quelle avait été la réponse
df[df['per_premiere_demande']==df['per_derniere_demande']]['reponse'].value_counts()
# Out:
# SANS_TRAITEMENT    441
# OUI                205
# REFUS_115          128
# REFUS_USAGER        92
# Name: reponse, dtype: int64

# %%
demandes_dates[demandes_dates['dem_date_count'] > 20]
# Out:
#         per_id   dem_date  per_id_max dem_date_max  per_id_count  \
